# %% [markdown]
# # IPSL-AID — Training Notebook
#
# **Author:** Kishanthan Kingston
# **Institution:** IPSL / CNRS / Sorbonne University
# **Year:** 2026
#
# ---
#
# This notebook provides a reproducible example of how to:
# - configure an experiment
# - launch training
#
# This notebook is intended for experimentation only.
# For large-scale or production runs, please use the SLURM pipeline.

# %%
# Environment setup (uv)
#
# To use the project's uv virtual environment in Jupyter Notebook:
#
# 1. Activate the environment:
#       source .venv/bin/activate
#
# 2. Register the environment as a Jupyter kernel:
#       python -m ipykernel install --user --name ipsl_aid --display-name "IPSL-AID (uv)"
#
# 3. In the notebook interface, select the kernel:
#       Kernel → Change Kernel → "IPSL-AID (uv)"
#
# The notebook will then run using the uv environment.

# %% [markdown]
# ## **Command Description**
#
# The following command builds and executes a full IPSL-AID experiment from the notebook.
#
# It performs three main steps:
# 1. **Set environment variables**
#    Adds the project directory to `PYTHONPATH` to ensure modules are found.
#
# 2. **Set working directory**
#    Moves to the project root so that `python -m IPSL_AID.main` runs correctly.
#
# 3. **Run the training pipeline**
#    Launches the main IPSL-AID script with all required parameters:
#    - experiment configuration (folders, naming)
#    - model architecture and diffusion settings
#    - dataset paths and variables
#    - training hyperparameters
#
# ### **Model Types and Preconditioning**
#
# IPSL-AID supports multiple model formulations through the `--precond` argument.
# This parameter fully defines the model formulation, including the architecture behavior and loss function.
#
# #### **Available options:**
#
# - **Diffusion models**
#   - `--precond vp` → VP preconditioning + `VPLoss`
#   - `--precond ve` → VE preconditioning + `VELoss`
#   - `--precond edm` → EDM preconditioning + `EDMLoss` *(default)*
#
# - **Direct U-Net**
#   - `--precond unet` → standard U-Net + `UnetLoss`
#
#   The architecture then depends on `--arch`:
#   - `adm` → Dhariwal U-Net
#   - `ddpmpp` or `ncsnpp` → Song U-Net
#
# #### **Input channels configuration**
#
# The definition of `in_channels` depends on the model type:
#
# - **Diffusion models**
#   - `in_channels = number of variables`
#   - `cond_channels = number of variables + constants (lat, lon, lsm, z)`
#
# - **U-Net**
#   - `in_channels = variables + constants + conditioning`
#   - `no cond_channels`
#
# This is a key difference between diffusion and U-Net models and must be set correctly to avoid shape mismatches.
#
# #### **Inference behavior**
#
# - Diffusion models require:
#   - `--inference_type sampler`
#
# - U-Net uses:
#   - `--inference_type direct`
#
# These parameters must be consistent:
# - Diffusion + `sampler`
# - U-Net + `direct`

# %% [markdown]
# ### **Parameter overview**
#
# This setup includes several parameters that can be grouped into the following categories:
#
# #### **Experiment configuration**
# - `--main_folder`, `--sub_folder`, `--prefix`
#   Define the output structure and naming of the experiment.
# - `--run_type`
#   Defines the execution mode (`train`, `resume_train`, `inference`, `inference_regional`).
#
#
# #### **Checkpoint**
# - `--save_model`
#   Enable/disable checkpoint saving.
# - `--save_checkpoint_name`
#   Base name used for saving checkpoints.
# - `--load_checkpoint_name`
#   Checkpoint file to load (for resume or inference).
# - `--save_per_samples`
#   Frequency of checkpoint saving.
#
#
# #### **Model configuration**
# - `--arch`
#   Model architecture (`adm`, `ddpmpp`, `ncsnpp`).
# - `--precond`
#   Defines the model type (diffusion or U-Net).
# - `--in_channels`, `--cond_channels`, `--out_channels`
#   Define input/output tensor structure.
# - `--inference_type`
#   `sampler` (diffusion) or `direct` (U-Net).
#
#
# #### **Data configuration**
# - `--datadir`
#   Path to dataset.
# - `--per_var_datadir`
#   Per-variable data paths.
# - `--varnames_list`
#   Variables used for training.
# - `--constant_varnames_list`
#   Static variables (e.g. `z`, `lsm`).
# - `--units_list`
#   Units corresponding to each variable.
# - `--normalization_types`
#   Normalization method per variable.
#
#
# #### **Time configuration**
# - `--year_start`, `--year_end`
#   Training period.
# - `--year_start_test`, `--year_end_test`
#   Validation period.
# - `--time_normalization`
#   Encoding of temporal features (`linear`, `cos_sin`).
#
#
# #### **Training parameters**
# - `--batch_size`
#   Number of samples per batch.
# - `--num_epochs`
#   Number of training epochs.
# - `--learning_rate`
#   Optimizer learning rate.
# - `--num_workers`
#   Data loading workers.
#
#
# #### **Spatial & temporal batching**
# - `--tbatch`
#   Temporal batch length.
# - `--sbatch`
#   Number of spatial batches.
# - `--batch_size_lat`, `--batch_size_lon`
#   Spatial patch size.
#
#
# #### **Data processing**
# - `--epsilon`, `--beta`, `--margin`
#   Parameters controlling filtering behavior.
# - `--apply_filter`
#   Enable/disable filtering.
#
#
# #### **Diffusion sampler (only for diffusion models)**
# - `--num_steps`
#   Number of sampling steps.
# - `--sigma_min`, `--sigma_max`
#   Noise schedule range.
# - `--rho`
#   Time discretization parameter.
# - `--s_churn`
#   Stochasticity strength.
# - `--solver`
#   Numerical solver (`heun`, `euler`).
#
#
# #### **Evaluation**
# - `--compute_crps`
#   Enable probabilistic evaluation (diffusion only).

# %% [markdown]
# ## Diffusion Model — Training Command
#
# This example runs a **simple training configuration**:
# - **1 year of training data** (2019)
# - **1 year of validation data** (2020)
# - **1 epoch only**
#
# It is intended for quick testing and validation of the pipeline.
#
# ### Outputs
#
# All outputs are saved in the following directories:
#
# - **Results (plots, diagnostics):**
#   `results/notebook_test/test_run_diffusion`
#
# - **Logs:**
#   `logs/notebook_test/test_run_diffusion`
#
# - **Checkpoints:**
#   `checkpoints/notebook_test/test_run_diffusion`

# %%
cmd = """
export PYTHONPATH="/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID:$PYTHONPATH"

cd "/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID"

python -m IPSL_AID.main \
    --debug false \
    --main_folder notebook_test \
    --sub_folder test_run_diffusion \
    --prefix run_20260323_142528 \
    --run_type train \
    --save_model true \
    --save_checkpoint_name difusion_model \
    --load_checkpoint_name difusion_model \
    --save_per_samples 10000 \
    --inference_type sampler \
    --arch adm \
    --precond edm \
    --in_channels 1 \
    --cond_channels 5 \
    --out_channels 1 \
    --apply_filter false \
    --model_name notebook_test_run_diffusion \
    --varnames_list VAR_2T \
    --normalization_types VAR_2T=standard \
    --constant_varnames_list z lsm \
    --constant_varnames_file ERA5_const_sfc_variables.nc \
    --units_list K \
    --year_start 2019 \
    --year_end 2019 \
    --year_start_test 2020 \
    --year_end_test 2020 \
    --batch_size 70 \
    --num_epochs 1 \
    --learning_rate 0.0001 \
    --num_workers 8 \
    --datadir /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily \
    --per_var_datadir VAR_2T=/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily \
    --time_normalization cos_sin \
    --tbatch 1800 \
    --sbatch 12 \
    --batch_size_lat 145 \
    --batch_size_lon 361 \
    --epsilon 0.02 \
    --beta 1.0 \
    --margin 8 \
    --dynamic_covariates_dir ../data_covariates/ \
    --dtype fp32 \
    --num_steps 10 \
    --sigma_min 0.002 \
    --sigma_max 80.0 \
    --rho 7 \
    --s_churn 40 \
    --solver heun \
    --compute_crps false
"""

# %%
# Use bash -c to ensure all commands (export, cd, python) run in the same environment
# !bash -c "{cmd}"
# Out:
# ╭────────────────────────── IPSL AI Downscaling Tool ──────────────────────────╮
# │ 🚀 Starting Module: Main                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [INFO] ============================================================
# [INFO] CONFIGURATION PARAMETERS
# [INFO] ============================================================
# [INFO] Execution Mode:
# [INFO]  └── Debug: False
# [INFO]  └── Run type: 'train'
# [INFO]  └── Inference type: 'sampler'
# [INFO]  └── Region: 'None'
# [INFO]  └── Apply filter: False
# [INFO]
# Checkpoint Configuration:
# [INFO]  └── Save model: True
# [INFO]  └── Save checkpoint name: 'difusion_model'
# [INFO]  └── Load checkpoint name: 'difusion_model'
# [INFO]  └── Save per samples: 10000
# [INFO]  └── Model name: 'notebook_test_run_diffusion'
# [INFO]
# Data Configuration:
# [INFO]  └── Variable names: ['VAR_2T']
# [INFO]  └── Constant variables: ['z', 'lsm']
# [INFO]  └── Constant variables file: 'ERA5_const_sfc_variables.nc'
# [INFO]  └── Dynamic covariates: None
# [INFO]  └── Dynamic covariates dir: '../data_covariates/'
# [INFO]  └── Units list: ['K']
# [INFO]  └── Normalization types: ['VAR_2T=standard']
# [INFO]  └── Data directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]
# Time Range Configuration:
# [INFO]  └── Training years: 2019-2019
# [INFO]  └── Test years: 2020-2020
# [INFO]  └── Time normalization: 'cos_sin'
# [INFO]
# Training Configuration:
# [INFO]  └── Number of epochs: 1
# [INFO]  └── Batch size: 70
# [INFO]  └── Number of workers: 8
# [INFO]  └── Learning rate: 0.0001
# [INFO]  └── Dtype: 'fp32'
# [INFO]
# Spatial-Temporal Batching:
# [INFO]  └── Spatial batches: 12
# [INFO]  └── Temporal time steps: 1800
# [INFO]  └── Batch size (lat): 145 grid points
# [INFO]  └── Batch size (lon): 361 grid points
# [INFO]
# Data Processing Parameters:
# [INFO]  └── Epsilon: 0.02
# [INFO]  └── Beta: 1.0
# [INFO]  └── Margin: 8
# [INFO]
# Model Architecture:
# [INFO]  └── Architecture: 'adm'
# [INFO]  └── Preconditioner: 'edm'
# [INFO]  └── Input channels: 1
# [INFO]  └── Conditioning channels: 5
# [INFO]  └── Output channels: 1
# [INFO]
# Sampler Configuration:
# [INFO]  └── solver: heun
# [INFO]  └── num_steps: 10
# [INFO]  └── sigma_min: 0.002
# [INFO]  └── sigma_max: 80.0
# [INFO]  └── rho: 7.0
# [INFO]  └── s_churn: 40.0
# [INFO]  └── s_min: 0
# [INFO]  └── s_max: inf
# [INFO]  └── s_noise: 1.0
# [INFO]
# Output Configuration:
# [INFO]  └── Main folder: 'notebook_test'
# [INFO]  └── Sub folder: 'test_run_diffusion'
# [INFO]  └── Prefix: 'run_20260323_142528'
# [INFO]
# Generated Directory Paths:
# [INFO]  └── Logs directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/logs/notebook_test/test_run_dif
# fusion'
# [INFO]  └── Results directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_
# diffusion'
# [INFO]  └── TensorBoard runs:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/runs/notebook_test/test_run_dif
# fusion'
# [INFO]  └── Model checkpoints:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_
# run_diffusion'
# [INFO]  └── Statistics:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats/notebook_test/test_run_di
# ffusion'
# [INFO]  └── Statistics: '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats'
# [INFO]  └── Data directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]  └── Constants file:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5
# _const_sfc_variables.nc'
# [INFO]
# Per-variable data directories:
# [INFO]  └── VAR_2T:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]
# Run Type Notes:
# [INFO]  └── Mode: Training from scratch
# [INFO]
# Checkpoint Saving Strategy:
# [INFO]  └── Checkpoints enabled:
# [INFO]  └── Saving every 10,000 samples
# [INFO]  └── Saving epoch checkpoints every 10 epochs
# [INFO]  └── Saving best model based on validation MAE
# [INFO]  └── Saving final model at end of training
# [INFO]  └── Each checkpoint includes:
# [INFO]      └── Model state dict
# [INFO]      └── Optimizer state
# [INFO]      └── Training/validation history
# [INFO]      └── Metrics history
# [INFO]      └── Training state (epoch, samples processed)
# [INFO]      └── Configuration arguments
# [INFO] ============================================================
# [INFO] Training years: [2019]
# [INFO] Testing years: [2020]
# [INFO] [Data paths] default →
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily
# [INFO] Pre-loading training datasets...
# [INFO] VAR_2T training files:
# [
#   /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/sam
# ples_2019.nc
# ]
# [INFO] Training dataset concatenated: Frozen({'time': 1460, 'latitude': 721,
# 'longitude': 1440})
# [INFO] Pre-loading validation datasets...
# [INFO] VAR_2T validation files:
# [
#   /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/sam
# ples_2020.nc
# ]
# [INFO] Validation dataset concatenated: Frozen({'time': 1464, 'latitude': 721,
# 'longitude': 1440})
# [INFO] Starting statistics computation...
# [INFO] Loading normalization statistics from
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats/statistics.json
# [INFO] ------------------------------------------
# [INFO] [COORD] Skipping time coordinate 'time' (datetime64)
# [INFO] ------ Coordinate / Dimension Sizes ------
# [INFO]  └── longitude: 1440
# [INFO]  └── d_longitude: 0.25
# [INFO]  └── latitude: 721
# [INFO]  └── d_latitude: 0.25
# [INFO]  └── time: 1464
# [INFO]  └── d_time: 36000000000000 nanoseconds
# [INFO] ------------------------------------------
# [INFO] Normalization types: {'VAR_2T': 'standard'}
# [INFO] VAR_2T: Index 0
# [INFO] ------ Normalization Statistics (norm_mapping) ------
# [INFO]
# [VAR_2T_fine]
#  └── vmin=229.04872131347656
#  └── vmax=321.4019470214844
#  └── vmean=286.3158874511719
#  └── vstd=12.632543563842773
#  └── median=289.16717529296875
#  └── iqr=17.32952880859375
#  └── q1=278.6593017578125
#  └── q3=295.98883056640625
# [INFO]
# [VAR_10U_fine]
#  └── vmin=-31.68634033203125
#  └── vmax=27.692642211914062
#  └── vmean=0.36626559495925903
#  └── vstd=3.4527664184570312
#  └── median=0.406768798828125
#  └── iqr=3.959686279296875
#  └── q1=-1.5895233154296875
#  └── q3=2.3701629638671875
# [INFO]
# [VAR_10V_fine]
#  └── vmin=-25.834945678710938
#  └── vmax=31.813018798828125
#  └── vmean=-0.05726669356226921
#  └── vstd=3.699695110321045
#  └── median=0.1490478515625
#  └── iqr=4.2974090576171875
#  └── q1=-2.101776123046875
#  └── q3=2.1956329345703125
# [INFO]
# [VAR_TP_fine]
#  └── vmin=0.0
#  └── vmax=0.03237342834472656
#  └── vmean=9.736002539284527e-05
#  └── vstd=0.0004453345318324864
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_fine]
#  └── vmin=225.20355224609375
#  └── vmax=303.56671142578125
#  └── vmean=280.1187744140625
#  └── vstd=12.384744644165039
#  └── median=282.1183776855469
#  └── iqr=17.892791748046875
#  └── q1=271.99053955078125
#  └── q3=289.8833312988281
# [INFO]
# [VAR_SSTK_fine]
#  └── vmin=269.893798828125
#  └── vmax=310.327392578125
#  └── vmean=294.448974609375
#  └── vstd=7.419081211090088
#  └── median=296.134521484375
#  └── iqr=8.3564453125
#  └── q1=291.531005859375
#  └── q3=299.887451171875
# [INFO]
# [VAR_SKT_fine]
#  └── vmin=228.62649536132812
#  └── vmax=340.2298583984375
#  └── vmean=286.8110656738281
#  └── vstd=13.723491668701172
#  └── median=289.64111328125
#  └── iqr=18.9613037109375
#  └── q1=278.0294189453125
#  └── q3=296.99072265625
# [INFO]
# [VAR_ST_fine]
#  └── vmin=228.62649536132812
#  └── vmax=340.2298583984375
#  └── vmean=286.93658447265625
#  └── vstd=13.66016674041748
#  └── median=289.69012451171875
#  └── iqr=19.09234619140625
#  └── q1=278.03558349609375
#  └── q3=297.1279296875
# [INFO]
# [VAR_TCWV_fine]
#  └── vmin=0.22132164239883423
#  └── vmax=85.15592193603516
#  └── vmean=19.793996810913086
#  └── vstd=13.685070037841797
#  └── median=16.279447555541992
#  └── iqr=20.19249439239502
#  └── q1=8.689061164855957
#  └── q3=28.881555557250977
# [INFO]
# [VAR_2T_fine_log]
#  └── vmin=5.438291072845459
#  └── vmax=5.77579927444458
#  └── vmean=5.659588813781738
#  └── vstd=0.0450122207403183
#  └── median=5.670457363128662
#  └── iqr=0.06012248992919922
#  └── q1=5.633572101593018
#  └── q3=5.693694591522217
# [INFO]
# [VAR_10U_fine_log]
#  └── vmin=0.0
#  └── vmax=3.3566408157348633
#  └── vmean=0.630792498588562
#  └── vstd=0.7104994654655457
#  └── median=0.341295450925827
#  └── iqr=1.214961051940918
#  └── q1=0.0
#  └── q3=1.214961051940918
# [INFO]
# [VAR_10V_fine_log]
#  └── vmin=0.0
#  └── vmax=3.4908254146575928
#  └── vmean=0.5861193537712097
#  └── vstd=0.6988515257835388
#  └── median=0.13893364369869232
#  └── iqr=1.1617851257324219
#  └── q1=0.0
#  └── q3=1.1617851257324219
# [INFO]
# [VAR_TP_fine_log]
#  └── vmin=0.0
#  └── vmax=0.03186045214533806
#  └── vmean=9.725653217174113e-05
#  └── vstd=0.0004441823693923652
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_fine_log]
#  └── vmin=5.421435356140137
#  └── vmax=5.718890190124512
#  └── vmean=5.637784481048584
#  └── vstd=0.04488770291209221
#  └── median=5.645864963531494
#  └── iqr=0.06348514556884766
#  └── q1=5.609436988830566
#  └── q3=5.672922134399414
# [INFO]
# [VAR_SSTK_fine_log]
#  └── vmin=5.60172700881958
#  └── vmax=5.740845203399658
#  └── vmean=5.688181400299072
#  └── vstd=0.025550369173288345
#  └── median=5.69418478012085
#  └── iqr=0.028165340423583984
#  └── q1=5.678570747375488
#  └── q3=5.706736087799072
# [INFO]
# [VAR_SKT_fine_log]
#  └── vmin=5.436453819274902
#  └── vmax=5.832556247711182
#  └── vmean=5.661135196685791
#  └── vstd=0.04862700030207634
#  └── median=5.672089099884033
#  └── iqr=0.06574535369873047
#  └── q1=5.631317138671875
#  └── q3=5.6970624923706055
# [INFO]
# [VAR_ST_fine_log]
#  └── vmin=5.436453819274902
#  └── vmax=5.832556247711182
#  └── vmean=5.661587715148926
#  └── vstd=0.048360396176576614
#  └── median=5.672257900238037
#  └── iqr=0.06618309020996094
#  └── q1=5.6313395500183105
#  └── q3=5.6975226402282715
# [INFO]
# [VAR_TCWV_fine_log]
#  └── vmin=0.19993358850479126
#  └── vmax=4.456158638000488
#  └── vmean=2.7831106185913086
#  └── vstd=0.7609286904335022
#  └── median=2.849517822265625
#  └── iqr=1.1262438297271729
#  └── q1=2.2709975242614746
#  └── q3=3.3972413539886475
# [INFO]
# [VAR_2T_coarse]
#  └── vmin=231.1106414794922
#  └── vmax=317.4587097167969
#  └── vmean=286.2744445800781
#  └── vstd=12.475735664367676
#  └── median=289.1328125
#  └── iqr=17.11468505859375
#  └── q1=278.7331237792969
#  └── q3=295.8478088378906
# [INFO]
# [VAR_10U_coarse]
#  └── vmin=-21.51896095275879
#  └── vmax=21.438461303710938
#  └── vmean=0.3791687488555908
#  └── vstd=3.261948585510254
#  └── median=0.4203634262084961
#  └── iqr=3.678152084350586
#  └── q1=-1.411860466003418
#  └── q3=2.266291618347168
# [INFO]
# [VAR_10V_coarse]
#  └── vmin=-22.52874183654785
#  └── vmax=22.988109588623047
#  └── vmean=-0.05645933374762535
#  └── vstd=3.4837522506713867
#  └── median=0.14693546295166016
#  └── iqr=4.036676406860352
#  └── q1=-1.9780120849609375
#  └── q3=2.058664321899414
# [INFO]
# [VAR_TP_coarse]
#  └── vmin=0.0
#  └── vmax=0.023218277841806412
#  └── vmean=9.832954674493521e-05
#  └── vstd=0.0003440176951698959
#  └── median=0.0
#  └── iqr=3.2697804272174835e-05
#  └── q1=0.0
#  └── q3=3.2697804272174835e-05
# [INFO]
# [VAR_D2M_coarse]
#  └── vmin=227.51480102539062
#  └── vmax=301.0519714355469
#  └── vmean=280.09478759765625
#  └── vstd=12.215740203857422
#  └── median=281.9904479980469
#  └── iqr=17.661468505859375
#  └── q1=272.05743408203125
#  └── q3=289.7189025878906
# [INFO]
# [VAR_SSTK_coarse]
#  └── vmin=270.34332275390625
#  └── vmax=305.5076599121094
#  └── vmean=292.5169982910156
#  └── vstd=8.795150756835938
#  └── median=294.7130126953125
#  └── iqr=10.933807373046875
#  └── q1=288.31317138671875
#  └── q3=299.2469787597656
# [INFO]
# [VAR_SKT_coarse]
#  └── vmin=231.03900146484375
#  └── vmax=334.51080322265625
#  └── vmean=286.7804260253906
#  └── vstd=13.49194049835205
#  └── median=289.6012878417969
#  └── iqr=18.774444580078125
#  └── q1=278.14044189453125
#  └── q3=296.9148864746094
# [INFO]
# [VAR_ST_coarse]
#  └── vmin=231.0741424560547
#  └── vmax=334.51080322265625
#  └── vmean=286.9049377441406
#  └── vstd=13.402721405029297
#  └── median=289.6504211425781
#  └── iqr=18.90411376953125
#  └── q1=278.1444396972656
#  └── q3=297.0485534667969
# [INFO]
# [VAR_TCWV_coarse]
#  └── vmin=0.4617171883583069
#  └── vmax=75.78866577148438
#  └── vmean=19.75491714477539
#  └── vstd=13.40636920928955
#  └── median=16.368555068969727
#  └── iqr=19.981657028198242
#  └── q1=8.836700439453125
#  └── q3=28.818357467651367
# [INFO]
# [VAR_2T_coarse_log]
#  └── vmin=5.447214126586914
#  └── vmax=5.763493061065674
#  └── vmean=5.659465312957764
#  └── vstd=0.044454626739025116
#  └── median=5.6703386306762695
#  └── iqr=0.05938386917114258
#  └── q1=5.633835792541504
#  └── q3=5.6932196617126465
# [INFO]
# [VAR_10U_coarse_log]
#  └── vmin=0.0
#  └── vmax=3.110776424407959
#  └── vmean=0.6167603731155396
#  └── vstd=0.6906296610832214
#  └── median=0.35091277956962585
#  └── iqr=1.1836552619934082
#  └── q1=0.0
#  └── q3=1.1836552619934082
# [INFO]
# [VAR_10V_coarse_log]
#  └── vmin=0.0
#  └── vmax=3.177558183670044
#  └── vmean=0.5649643540382385
#  └── vstd=0.6782220005989075
#  └── median=0.13709357380867004
#  └── iqr=1.1179783344268799
#  └── q1=0.0
#  └── q3=1.1179783344268799
# [INFO]
# [VAR_TP_coarse_log]
#  └── vmin=0.0
#  └── vmax=0.022952834144234657
#  └── vmean=9.826572932070121e-05
#  └── vstd=0.0003434800310060382
#  └── median=0.0
#  └── iqr=3.269726948929019e-05
#  └── q1=0.0
#  └── q3=3.269726948929019e-05
# [INFO]
# [VAR_D2M_coarse_log]
#  └── vmin=5.431601047515869
#  └── vmax=5.710598945617676
#  └── vmean=5.637722492218018
#  └── vstd=0.04426100477576256
#  └── median=5.645412921905518
#  └── iqr=0.06267452239990234
#  └── q1=5.609682083129883
#  └── q3=5.672356605529785
# [INFO]
# [VAR_SSTK_coarse_log]
#  └── vmin=5.603384971618652
#  └── vmax=5.725242614746094
#  └── vmean=5.68147611618042
#  └── vstd=0.03042922541499138
#  └── median=5.689389228820801
#  └── iqr=0.03709602355957031
#  └── q1=5.66750955581665
#  └── q3=5.704605579376221
# [INFO]
# [VAR_SKT_coarse_log]
#  └── vmin=5.446905612945557
#  └── vmax=5.815654277801514
#  └── vmean=5.661067962646484
#  └── vstd=0.04781469702720642
#  └── median=5.671952247619629
#  └── iqr=0.0650930404663086
#  └── q1=5.631714820861816
#  └── q3=5.696807861328125
# [INFO]
# [VAR_ST_coarse_log]
#  └── vmin=5.447056770324707
#  └── vmax=5.815654277801514
#  └── vmean=5.6615166664123535
#  └── vstd=0.04743646830320358
#  └── median=5.672121047973633
#  └── iqr=0.06552743911743164
#  └── q1=5.6317291259765625
#  └── q3=5.697256565093994
# [INFO]
# [VAR_TCWV_coarse_log]
#  └── vmin=0.37961190938949585
#  └── vmax=4.341056823730469
#  └── vmean=2.7900803089141846
#  └── vstd=0.7469266057014465
#  └── median=2.854661464691162
#  └── iqr=1.1090037822723389
#  └── q1=2.2861204147338867
#  └── q3=3.3951241970062256
# [INFO]
# [VAR_2T_residual]
#  └── vmin=-20.920257568359375
#  └── vmax=21.579376220703125
#  └── vmean=0.04164712503552437
#  └── vstd=1.5219651460647583
#  └── median=0.030517578125
#  └── iqr=0.98223876953125
#  └── q1=-0.43994140625
#  └── q3=0.54229736328125
# [INFO]
# [VAR_10U_residual]
#  └── vmin=-29.087757110595703
#  └── vmax=29.122817993164062
#  └── vmean=-0.012903066352009773
#  └── vstd=0.9604038000106812
#  └── median=-0.010351181030273438
#  └── iqr=0.8234825134277344
#  └── q1=-0.4233999252319336
#  └── q3=0.4000825881958008
# [INFO]
# [VAR_10V_residual]
#  └── vmin=-30.490480422973633
#  └── vmax=33.75514221191406
#  └── vmean=-0.0008073379285633564
#  └── vstd=0.9775290489196777
#  └── median=-0.0026082992553710938
#  └── iqr=0.8361549377441406
#  └── q1=-0.41808319091796875
#  └── q3=0.4180717468261719
# [INFO]
# [VAR_TP_residual]
#  └── vmin=-0.017026737332344055
#  └── vmax=0.029841333627700806
#  └── vmean=-9.694650771052693e-07
#  └── vstd=0.00030207826057448983
#  └── median=0.0
#  └── iqr=5.470588803291321e-06
#  └── q1=-5.470588803291321e-06
#  └── q3=0.0
# [INFO]
# [VAR_D2M_residual]
#  └── vmin=-31.039138793945312
#  └── vmax=28.3192138671875
#  └── vmean=0.023892996832728386
#  └── vstd=1.4677867889404297
#  └── median=0.0244140625
#  └── iqr=0.987335205078125
#  └── q1=-0.45941162109375
#  └── q3=0.527923583984375
# [INFO]
# [VAR_SSTK_residual]
#  └── vmin=-17.443267822265625
#  └── vmax=13.81427001953125
#  └── vmean=-0.0350143201649189
#  └── vstd=0.7585651874542236
#  └── median=0.001617431640625
#  └── iqr=0.376678466796875
#  └── q1=-0.188629150390625
#  └── q3=0.18804931640625
# [INFO]
# [VAR_SKT_residual]
#  └── vmin=-28.566864013671875
#  └── vmax=28.982437133789062
#  └── vmean=0.03118680603802204
#  └── vstd=2.0454213619232178
#  └── median=0.019866943359375
#  └── iqr=1.16064453125
#  └── q1=-0.5408935546875
#  └── q3=0.6197509765625
# [INFO]
# [VAR_ST_residual]
#  └── vmin=-34.95600891113281
#  └── vmax=39.09918212890625
#  └── vmean=0.03217749670147896
#  └── vstd=2.273470878601074
#  └── median=0.019073486328125
#  └── iqr=1.18994140625
#  └── q1=-0.560211181640625
#  └── q3=0.629730224609375
# [INFO]
# [VAR_TCWV_residual]
#  └── vmin=-23.256834030151367
#  └── vmax=37.254486083984375
#  └── vmean=0.039075303822755814
#  └── vstd=1.738486886024475
#  └── median=-0.006313323974609375
#  └── iqr=1.2740097045898438
#  └── q1=-0.6151771545410156
#  └── q3=0.6588325500488281
# [INFO]
# [VAR_2T_residual_log]
#  └── vmin=0.0
#  └── vmax=3.117036819458008
#  └── vmean=0.28070369362831116
#  └── vstd=0.4261401295661926
#  └── median=0.030061179772019386
#  └── iqr=0.4332731068134308
#  └── q1=0.0
#  └── q3=0.4332731068134308
# [INFO]
# [VAR_10U_residual_log]
#  └── vmin=0.0
#  └── vmax=3.405282974243164
#  └── vmean=0.20981374382972717
#  └── vstd=0.3211251497268677
#  └── median=0.0
#  └── iqr=0.33653122186660767
#  └── q1=0.0
#  └── q3=0.33653122186660767
# [INFO]
# [VAR_10V_residual_log]
#  └── vmin=0.0
#  └── vmax=3.5483274459838867
#  └── vmean=0.2159300297498703
#  └── vstd=0.3264327943325043
#  └── median=0.0
#  └── iqr=0.34929803013801575
#  └── q1=0.0
#  └── q3=0.34929803013801575
# [INFO]
# [VAR_TP_residual_log]
#  └── vmin=0.0
#  └── vmax=0.029404744505882263
#  └── vmean=3.573554931790568e-05
#  └── vstd=0.00025026267394423485
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_residual_log]
#  └── vmin=0.0
#  └── vmax=3.3782429695129395
#  └── vmean=0.2696094512939453
#  └── vstd=0.4076869487762451
#  └── median=0.02412080205976963
#  └── iqr=0.4239096939563751
#  └── q1=0.0
#  └── q3=0.4239096939563751
# [INFO]
# [VAR_SSTK_residual_log]
#  └── vmin=0.0
#  └── vmax=2.6955909729003906
#  └── vmean=0.13331298530101776
#  └── vstd=0.24127879738807678
#  └── median=0.0016161249950528145
#  └── iqr=0.17231273651123047
#  └── q1=0.0
#  └── q3=0.17231273651123047
# [INFO]
# [VAR_SKT_residual_log]
#  └── vmin=0.0
#  └── vmax=3.4006118774414062
#  └── vmean=0.3152047395706177
#  └── vstd=0.4903116822242737
#  └── median=0.019672170281410217
#  └── iqr=0.4822724163532257
#  └── q1=0.0
#  └── q3=0.4822724163532257
# [INFO]
# [VAR_ST_residual_log]
#  └── vmin=0.0
#  └── vmax=3.6913559436798096
#  └── vmean=0.3226388692855835
#  └── vstd=0.5073100328445435
#  └── median=0.01889386773109436
#  └── iqr=0.4884144961833954
#  └── q1=0.0
#  └── q3=0.4884144961833954
# [INFO]
# [VAR_TCWV_residual_log]
#  └── vmin=0.0
#  └── vmax=3.644260883331299
#  └── vmean=0.30773696303367615
#  └── vstd=0.4650293290615082
#  └── median=0.0
#  └── iqr=0.5061140656471252
#  └── q1=0.0
#  └── q3=0.5061140656471252
# [INFO]
#
#  └── vmin=0.0
#  └── vmax=359.75
#  └── vmean=179.875
#  └── vstd=103.92301940917969
#  └── median=None
#  └── iqr=None
#  └── q1=None
#  └── q3=None
# [INFO]
#
#  └── vmin=-90.0
#  └── vmax=90.0
#  └── vmean=0.0
#  └── vstd=52.03364181518555
#  └── median=None
#  └── iqr=None
#  └── q1=None
#  └── q3=None
# [INFO] ------------------------------------------------------
# [INFO] Using device: cuda
# [INFO] TensorBoard enabled at: runs/notebook_test/test_run_diffusion/
# [INFO] Creating train dataset:
# [INFO]  └── Original resolution: (145, 361)
# [INFO]  └── Adjusted to divisible-by-2^3 resolution: (144, 360)
# [INFO]  └── train years: [2019]
# [INFO]  └── train parameters - tbatch: 1800, sbatch: 12, shuffle: True
# [INFO]  └── Number of train files: 1
# [INFO] Spatial dimensions: 721 x 1440
# [INFO] batch size: 144 x 360
# [INFO] Opening constant variables file:
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5_
# const_sfc_variables.nc
# [INFO] Normalizing z
# [INFO] z - Weighted Mean: 2270.3749, Weighted Std: 6149.4917
# [INFO] Loaded constant variables: ['z', 'lsm']
# [INFO] Constant variables shape: (2, 721, 1440)
# [INFO] Training mode: sbatch=12, tbatch=1800
# [INFO]   train dataset size: 17520
# [INFO]   train data loader batches: 251
# [INFO] Training dataset loaded with image resolution: (144, 360)
# [INFO] Creating validation dataset:
# [INFO]  └── Original resolution: (145, 361)
# [INFO]  └── Adjusted to divisible-by-2^3 resolution: (144, 360)
# [INFO]  └── validation years: [2020]
# [INFO]  └── validation parameters - tbatch: 70, sbatch: 12, shuffle: False
# [INFO]  └── Number of validation files: 1
# [INFO] Spatial dimensions: 721 x 1440
# [INFO] batch size: 144 x 360
# [INFO] Opening constant variables file:
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5_
# const_sfc_variables.nc
# [INFO] Normalizing z
# [INFO] z - Weighted Mean: 2270.3749, Weighted Std: 6149.4917
# [INFO] Loaded constant variables: ['z', 'lsm']
# [INFO] Constant variables shape: (2, 721, 1440)
# [INFO] Generated 20 evaluation blocks (5 x 4 grid)
# [INFO] Evaluation mode: Generated 20 spatial slices
# [INFO] Validation time batches: [488 495 502 509 516 523 530 537 544 551 558 565
# 572 579 587 594 601 608
#  615 622 629 636 643 650 657 664 671 678 686 693 700 707 714 721 728 735
#  742 749 756 763 770 777 785 792 799 806 813 820 827 834 841 848 855 862
#  869 876 884 891 898 905 912 919 926 933 940 947 954 961 968 976]
# [INFO]   validation dataset size: 1400
# [INFO]   validation data loader batches: 20
# [INFO] Validation dataset loaded with image resolution: (144, 360)
# [INFO] ------ Model and Loss info ------
# [INFO] Label dimension: 4 (time_normalization: cos_sin)
# [INFO] Using EDM preconditioner & EDMLoss
# [INFO] Architecture ADM / DhariwalUNet selected
# [INFO] Instantiating model...
# [INFO] Diffusion model enabled
# [INFO] Model Summary:
# [INFO]    └── Model Type: EDMPrecond
# [INFO]    └── Preconditioner: EDM
# [INFO]    └── Architecture: ADM
# [INFO]    └── Input Channels: 6 (base: 1 + cond: 5)
# [INFO]    └── Output Channels: 1
# [INFO]    └── Label Dimension: 4
# [INFO]    └── Image Resolution: (144, 360)
# [INFO]    └── FP16 Enabled: False
# [INFO]    └── Model Parameters - Total: 92,130,177, Trainable: 92130177
# [INFO] Network Architecture:
# [INFO]    └── model_type: DhariwalUNet
# [INFO]    └── model_channels: 128
# [INFO]    └── channel_mult: [1, 2, 3, 4]
# [INFO]    └── num_blocks: 2
# [INFO] Device: cuda:0
# [INFO] Model Data Type: torch.float32
# [INFO] Loss function instantiated: EDMLoss
# [INFO]   └── Loss Type: EDM Diffusion Loss
# [INFO] Model Parameters - Total: 92,130,177, Trainable: 92,130,177
# [INFO] GradScaler initialized for CUDA
# [INFO] Tracking metrics: ['MAE', 'NMAE', 'RMSE', 'R2', 'PEARSON', 'KL']
# [INFO] Validation metrics: ['VAR_2T_pred_vs_fine_MAE',
# 'VAR_2T_coarse_vs_fine_MAE', 'VAR_2T_pred_vs_fine_NMAE',
# 'VAR_2T_coarse_vs_fine_NMAE', 'VAR_2T_pred_vs_fine_RMSE',
# 'VAR_2T_coarse_vs_fine_RMSE', 'VAR_2T_pred_vs_fine_R2',
# 'VAR_2T_coarse_vs_fine_R2', 'VAR_2T_pred_vs_fine_PEARSON',
# 'VAR_2T_coarse_vs_fine_PEARSON', 'VAR_2T_pred_vs_fine_KL',
# 'VAR_2T_coarse_vs_fine_KL', 'average_pred_vs_fine_MAE',
# 'average_coarse_vs_fine_MAE', 'average_pred_vs_fine_NMAE',
# 'average_coarse_vs_fine_NMAE', 'average_pred_vs_fine_RMSE',
# 'average_coarse_vs_fine_RMSE', 'average_pred_vs_fine_R2',
# 'average_coarse_vs_fine_R2', 'average_pred_vs_fine_PEARSON',
# 'average_coarse_vs_fine_PEARSON', 'average_pred_vs_fine_KL',
# 'average_coarse_vs_fine_KL']
# [INFO] Model saving enabled
# [INFO] Using 4 GPUs!
# [INFO] Start training...
# Training Epoch 0:   0%|                                 | 0/251 [00:00<?, ?it/s][INFO] batch idx:0, features shape:torch.Size([70, 5, 144, 360]), targets
# shape:torch.Size([70, 1, 144, 360])
# Training Epoch 0: 100%|█| 251/251 [08:47<00:00,  2.10s/it, Loss=0.0439, Avg Loss
# [INFO] Running validation for epoch 0...
# [INFO] EDM Sampler parameters: steps=10
# Validation Epoch 0:   0%|                                | 0/20 [00:00<?, ?it/s][INFO] Validation batch idx:0
# features shape:torch.Size([70, 5, 144, 360]), targets shape:torch.Size([70, 1,
# 144, 360])
# coarse shape:torch.Size([70, 1, 144, 360]), fine shape:torch.Size([70, 1, 144,
# 360])
# lat shape:torch.Size([70, 144]), lon shape:torch.Size([70, 360])
# [INFO] === Sampler Parameters ===
# [INFO]  └── num_steps: 10
# [INFO]  └── solver: heun
# [INFO]  └── discretization: edm
# [INFO]  └── schedule: linear
# [INFO]  └── scaling: none
# [INFO]  └── sigma_min: 0.002
# [INFO]  └── sigma_max: 80.0
# [INFO]  └── rho: 7.0
# [INFO]  └── S_churn: 40.0
# [INFO]  └── S_min: 0
# [INFO]  └── S_max: inf
# [INFO]  └── S_noise: 1.0
# [INFO]  └── epsilon_s: 0.001
# [INFO]  └── C_1: 0.001
# [INFO]  └── C_2: 0.008
# [INFO]  └── M: 1000
# [INFO]  └── alpha: 1
# [INFO] ==========================
# Validation Epoch 0: 100%|█| 20/20 [06:55<00:00, 20.77s/it, Val Loss=0.0419, Avg
# [INFO] Validation Epoch 0 - Average Loss: 0.0422
# [INFO] ============================================================
# [INFO] VALIDATION METRICS SUMMARY:
# [INFO] ============================================================
# [INFO] OVERALL MAE METRICS:
# [INFO]  └── Average Prediction vs Fine MAE: 1.6203 ± 0.0581
# [INFO]  └── Average Coarse vs Fine MAE: 0.7822 ± 0.0181
# [INFO]
# [INFO] OVERALL NMAE METRICS:
# [INFO]  └── Average Prediction vs Fine NMAE: 0.0058 ± 0.0002
# [INFO]  └── Average Coarse vs Fine NMAE: 0.0028 ± 0.0001
# [INFO]
# [INFO] OVERALL RMSE METRICS:
# [INFO]  └── Average Prediction vs Fine RMSE: 2.2618 ± 0.0695
# [INFO]  └── Average Coarse vs Fine RMSE: 1.4064 ± 0.0368
# [INFO]
# [INFO] OVERALL R2 METRICS:
# [INFO]  └── Average Prediction vs Fine R2: 0.9886 ± 0.0013
# [INFO]  └── Average Coarse vs Fine R2: 0.9956 ± 0.0006
# [INFO]
# [INFO] OVERALL PEARSON METRICS:
# [INFO]  └── Average Prediction vs Fine PEARSON: 0.9944 ± 0.0007
# [INFO]  └── Average Coarse vs Fine PEARSON: 0.9978 ± 0.0003
# [INFO]
# [INFO] OVERALL KL METRICS:
# [INFO]  └── Average Prediction vs Fine KL: 0.0154 ± 0.0061
# [INFO]  └── Average Coarse vs Fine KL: 0.0043 ± 0.0028
# [INFO]
# [INFO] PER-VARIABLE METRICS:
# [INFO]  └── VAR_2T:
# [INFO]    └── MAE:
# [INFO]        └── Model Pred vs Fine: 1.6203 ± 0.0581
# [INFO]        └── Coarse vs Fine:     0.7822 ± 0.0181
# [INFO]    └── NMAE:
# [INFO]        └── Model Pred vs Fine: 0.0058 ± 0.0002
# [INFO]        └── Coarse vs Fine:     0.0028 ± 0.0001
# [INFO]    └── RMSE:
# [INFO]        └── Model Pred vs Fine: 2.2618 ± 0.0695
# [INFO]        └── Coarse vs Fine:     1.4064 ± 0.0368
# [INFO]    └── R2:
# [INFO]        └── Model Pred vs Fine: 0.9886 ± 0.0013
# [INFO]        └── Coarse vs Fine:     0.9956 ± 0.0006
# [INFO]    └── PEARSON:
# [INFO]        └── Model Pred vs Fine: 0.9944 ± 0.0007
# [INFO]        └── Coarse vs Fine:     0.9978 ± 0.0003
# [INFO]    └── KL:
# [INFO]        └── Model Pred vs Fine: 0.0154 ± 0.0061
# [INFO]        └── Coarse vs Fine:     0.0043 ± 0.0028
# [INFO] Saved validation metrics heatmap to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_metrics_epoch_0.png
# [INFO] Reconstructing and plots ...
# [INFO] Dataset reconstruction info:
# [INFO]  └── time_batchs: 70
# [INFO]  └── sbatch: 20
# [INFO]  └── total dataset samples: 1400
# [INFO]  └── total batch samples: 1400
# [INFO] Sample shape: C=1, H=144, W=360
# [INFO] Initialized predictions with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized coarse with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized fine with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized lat with shape: torch.Size([70, 20, 144])
# [INFO] Initialized lon with shape: torch.Size([70, 20, 360])
# [INFO] Created index mapping for 1400 samples
# [INFO] Starting reconstruction process...
# [INFO] Processing batch 1/20 with size 70
# [INFO] Processing batch 2/20 with size 70
# [INFO] Processing batch 3/20 with size 70
# [INFO] Processing batch 4/20 with size 70
# [INFO] Processing batch 5/20 with size 70
# [INFO] Processing batch 6/20 with size 70
# [INFO] Processing batch 7/20 with size 70
# [INFO] Processing batch 8/20 with size 70
# [INFO] Processing batch 9/20 with size 70
# [INFO] Processing batch 10/20 with size 70
# [INFO] Processing batch 11/20 with size 70
# [INFO] Processing batch 12/20 with size 70
# [INFO] Processing batch 13/20 with size 70
# [INFO] Processing batch 14/20 with size 70
# [INFO] Processing batch 15/20 with size 70
# [INFO] Processing batch 16/20 with size 70
# [INFO] Processing batch 17/20 with size 70
# [INFO] Processing batch 18/20 with size 70
# [INFO] Processing batch 19/20 with size 70
# [INFO] Processing batch 20/20 with size 70
# [INFO] Successfully reconstructed 1400 samples
# [INFO] Reconstruction completed successfully
# [INFO] Generating block wise plots for epoch 0...
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=290.9628 | Pred=291.2077 | Coarse=290.6276
#   q=0.950 | Truth=294.1849 | Pred=294.4981 | Coarse=293.7257
#   q=0.975 | Truth=297.3305 | Pred=297.4895 | Coarse=296.7240
#   q=0.990 | Truth=300.1063 | Pred=300.4077 | Coarse=299.4454
#   q=0.995 | Truth=301.5690 | Pred=302.0803 | Coarse=300.9200
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_qq_epoch_0_spatial_block_000.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_hexbin_epoch_0_sblock_000.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_comparison_hexbin_epoch_0_sblock_000.png
# [PDF stats] Temperature [K]
#   Predictions: μ=279.935, σ=8.249
#   Ground Truth: μ=279.921, σ=8.091
#   Coarse: μ=279.920, σ=7.922
#   KL Divergence: 0.0393
#   Correlation: 0.9673
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_pdfs_epoch_0_sblock_000.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_power_spectra_epoch_0_sblock_000.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_mae_map_epoch_0_sblock_000.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_plot_surface_epoch_0_sblock_000.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_temporal_series_epoch_0_sblock_000.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=289.9468 | Pred=290.3457 | Coarse=289.4085
#   q=0.950 | Truth=293.5501 | Pred=293.9711 | Coarse=292.7796
#   q=0.975 | Truth=296.6164 | Pred=297.0274 | Coarse=295.9776
#   q=0.990 | Truth=299.7068 | Pred=300.1472 | Coarse=298.9757
#   q=0.995 | Truth=301.2311 | Pred=301.8429 | Coarse=300.3865
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_qq_epoch_0_spatial_block_001.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_hexbin_epoch_0_sblock_001.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_comparison_hexbin_epoch_0_sblock_001.png
# [PDF stats] Temperature [K]
#   Predictions: μ=278.504, σ=8.270
#   Ground Truth: μ=278.483, σ=8.004
#   Coarse: μ=278.483, σ=7.757
#   KL Divergence: 0.0568
#   Correlation: 0.9585
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_pdfs_epoch_0_sblock_001.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_power_spectra_epoch_0_sblock_001.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_mae_map_epoch_0_sblock_001.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_plot_surface_epoch_0_sblock_001.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train
png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_power_spectra_epoch_0_sblock_018.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_mae_map_epoch_0_sblock_018.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_plot_surface_epoch_0_sblock_018.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_temporal_series_epoch_0_sblock_018.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=273.5624 | Pred=274.3444 | Coarse=273.4959
#   q=0.950 | Truth=275.9487 | Pred=276.7397 | Coarse=275.7810
#   q=0.975 | Truth=277.5673 | Pred=278.5510 | Coarse=277.2873
#   q=0.990 | Truth=278.9640 | Pred=280.4070 | Coarse=278.6890
#   q=0.995 | Truth=279.7167 | Pred=281.5455 | Coarse=279.3722
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_qq_epoch_0_spatial_block_019.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_hexbin_epoch_0_sblock_019.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_comparison_hexbin_epoch_0_sblock_019.png
# [PDF stats] Temperature [K]
#   Predictions: μ=250.154, σ=18.756
#   Ground Truth: μ=250.054, σ=18.324
#   Coarse: μ=250.059, σ=17.986
#   KL Divergence: 0.0118
#   Correlation: 0.9849
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_validation_pdfs_epoch_0_sblock_019.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_power_spectra_epoch_0_sblock_019.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_mae_map_epoch_0_sblock_019.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_plot_surface_epoch_0_sblock_019.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_d
# iffusion/train_temporal_series_epoch_0_sblock_019.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [INFO] Scheduler step with mean validation MAE (all 1 epochs): 1.6203
# [INFO] Epoch 0 completed - Train Loss: 0.1112
# [INFO] Epoch 0 completed - Val Loss: 0.0422
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_epoch0000_difusion_model.pth.tar
# [INFO] ✅ Checkpoint saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_epoch0000_difusion_model.pth.tar
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_best_model.pth.tar
# [INFO] ✅ Best model saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_best_model.pth.tar
# [INFO]  └── Validation loss: 0.0422
# [INFO] Generating training summary plots...
# [INFO] Training summary plots generated successfully!
# [INFO] Generating spatiotemporal coverage plots...
# [INFO] Spatiotemporal coverage plots completed!
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_final_model_epoch1.pth.tar
# [INFO] ✅ Final model saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_diffusion/run_20260323_142528_final_model_epoch1.pth.tar
# [INFO]  └── Total samples: 0, Total batches: 0
# [INFO] Final model checkpoint saved successfully!
# [INFO] Training process completed successfully!

# %% [markdown]
# ## U-Net Model - Training Command
#
# This example runs a **simple training configuration**:
# - **1 year of training data** (2019)
# - **1 year of validation data** (2020)
# - **1 epoch only**
#
# It is intended for quick testing and validation of the pipeline.
#
# ### Outputs
#
# All outputs are saved in the following directories:
#
# - **Results (plots, diagnostics):**
#   `results/notebook_test/test_run_unet`
#
# - **Logs:**
#   `logs/notebook_test/test_run_unet`
#
# - **Checkpoints:**
#   `checkpoints/notebook_test/test_run_unet`

# %%
cmd = """
export PYTHONPATH="/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID:$PYTHONPATH"

cd "/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID"

python -m IPSL_AID.main \
    --debug false \
    --main_folder notebook_test \
    --sub_folder test_run_unet \
    --prefix run_20260323_142528 \
    --run_type train \
    --save_model true \
    --save_checkpoint_name unet_model \
    --load_checkpoint_name unet_model \
    --save_per_samples 10000 \
    --inference_type direct \
    --arch adm \
    --precond unet \
    --in_channels 5 \
    --out_channels 1 \
    --apply_filter false \
    --model_name notebook_test_run_unet \
    --varnames_list VAR_2T \
    --normalization_types VAR_2T=standard \
    --constant_varnames_list z lsm \
    --constant_varnames_file ERA5_const_sfc_variables.nc \
    --units_list K \
    --year_start 2019 \
    --year_end 2019 \
    --year_start_test 2020 \
    --year_end_test 2020 \
    --batch_size 70 \
    --num_epochs 1 \
    --learning_rate 0.0001 \
    --num_workers 8 \
    --datadir /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily \
    --per_var_datadir VAR_2T=/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily \
    --time_normalization cos_sin \
    --tbatch 1800 \
    --sbatch 12 \
    --batch_size_lat 145 \
    --batch_size_lon 361 \
    --epsilon 0.02 \
    --beta 1.0 \
    --margin 8 \
    --dynamic_covariates_dir ../data_covariates/ \
    --dtype fp32
"""

# %%
# Use bash -c to ensure all commands (export, cd, python) run in the same environment
# !bash -c "{cmd}"
# Out:
# ╭────────────────────────── IPSL AI Downscaling Tool ──────────────────────────╮
# │ 🚀 Starting Module: Main                                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# [INFO] ============================================================
# [INFO] CONFIGURATION PARAMETERS
# [INFO] ============================================================
# [INFO] Execution Mode:
# [INFO]  └── Debug: False
# [INFO]  └── Run type: 'train'
# [INFO]  └── Inference type: 'direct'
# [INFO]  └── Region: 'None'
# [INFO]  └── Apply filter: False
# [INFO]
# Checkpoint Configuration:
# [INFO]  └── Save model: True
# [INFO]  └── Save checkpoint name: 'unet_model'
# [INFO]  └── Load checkpoint name: 'unet_model'
# [INFO]  └── Save per samples: 10000
# [INFO]  └── Model name: 'notebook_test_run_unet'
# [INFO]
# Data Configuration:
# [INFO]  └── Variable names: ['VAR_2T']
# [INFO]  └── Constant variables: ['z', 'lsm']
# [INFO]  └── Constant variables file: 'ERA5_const_sfc_variables.nc'
# [INFO]  └── Dynamic covariates: None
# [INFO]  └── Dynamic covariates dir: '../data_covariates/'
# [INFO]  └── Units list: ['K']
# [INFO]  └── Normalization types: ['VAR_2T=standard']
# [INFO]  └── Data directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]
# Time Range Configuration:
# [INFO]  └── Training years: 2019-2019
# [INFO]  └── Test years: 2020-2020
# [INFO]  └── Time normalization: 'cos_sin'
# [INFO]
# Training Configuration:
# [INFO]  └── Number of epochs: 1
# [INFO]  └── Batch size: 70
# [INFO]  └── Number of workers: 8
# [INFO]  └── Learning rate: 0.0001
# [INFO]  └── Dtype: 'fp32'
# [INFO]
# Spatial-Temporal Batching:
# [INFO]  └── Spatial batches: 12
# [INFO]  └── Temporal time steps: 1800
# [INFO]  └── Batch size (lat): 145 grid points
# [INFO]  └── Batch size (lon): 361 grid points
# [INFO]
# Data Processing Parameters:
# [INFO]  └── Epsilon: 0.02
# [INFO]  └── Beta: 1.0
# [INFO]  └── Margin: 8
# [INFO]
# Model Architecture:
# [INFO]  └── Architecture: 'adm'
# [INFO]  └── Preconditioner: 'unet'
# [INFO]  └── Input channels: 5
# [INFO]  └── Conditioning channels: 0
# [INFO]  └── Output channels: 1
# [INFO]
# Sampler Configuration:
# [INFO]  └── solver: heun
# [INFO]  └── num_steps: 20
# [INFO]  └── sigma_min: 0.002
# [INFO]  └── sigma_max: 80.0
# [INFO]  └── rho: 7.0
# [INFO]  └── s_churn: 40
# [INFO]  └── s_min: 0
# [INFO]  └── s_max: inf
# [INFO]  └── s_noise: 1.0
# [INFO]
# Output Configuration:
# [INFO]  └── Main folder: 'notebook_test'
# [INFO]  └── Sub folder: 'test_run_unet'
# [INFO]  └── Prefix: 'run_20260323_142528'
# [INFO]
# Generated Directory Paths:
# [INFO]  └── Logs directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/logs/notebook_test/test_run_une
# t'
# [INFO]  └── Results directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_
# unet'
# [INFO]  └── TensorBoard runs:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/runs/notebook_test/test_run_une
# t'
# [INFO]  └── Model checkpoints:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_
# run_unet'
# [INFO]  └── Statistics:
# '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats/notebook_test/test_run_un
# et'
# [INFO]  └── Statistics: '/leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats'
# [INFO]  └── Data directory:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]  └── Constants file:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5
# _const_sfc_variables.nc'
# [INFO]
# Per-variable data directories:
# [INFO]  └── VAR_2T:
# '/leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily'
# [INFO]
# Run Type Notes:
# [INFO]  └── Mode: Training from scratch
# [INFO]
# Checkpoint Saving Strategy:
# [INFO]  └── Checkpoints enabled:
# [INFO]  └── Saving every 10,000 samples
# [INFO]  └── Saving epoch checkpoints every 10 epochs
# [INFO]  └── Saving best model based on validation MAE
# [INFO]  └── Saving final model at end of training
# [INFO]  └── Each checkpoint includes:
# [INFO]      └── Model state dict
# [INFO]      └── Optimizer state
# [INFO]      └── Training/validation history
# [INFO]      └── Metrics history
# [INFO]      └── Training state (epoch, samples processed)
# [INFO]      └── Configuration arguments
# [INFO] ============================================================
# [INFO] Training years: [2019]
# [INFO] Testing years: [2020]
# [INFO] [Data paths] default →
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily
# [INFO] Pre-loading training datasets...
# [INFO] VAR_2T training files:
# [
#   /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/sam
# ples_2019.nc
# ]
# [INFO] Training dataset concatenated: Frozen({'time': 1460, 'latitude': 721,
# 'longitude': 1440})
# [INFO] Pre-loading validation datasets...
# [INFO] VAR_2T validation files:
# [
#   /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/sam
# ples_2020.nc
# ]
# [INFO] Validation dataset concatenated: Frozen({'time': 1464, 'latitude': 721,
# 'longitude': 1440})
# [INFO] Starting statistics computation...
# [INFO] Loading normalization statistics from
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/stats/statistics.json
# [INFO] ------------------------------------------
# [INFO] [COORD] Skipping time coordinate 'time' (datetime64)
# [INFO] ------ Coordinate / Dimension Sizes ------
# [INFO]  └── longitude: 1440
# [INFO]  └── d_longitude: 0.25
# [INFO]  └── latitude: 721
# [INFO]  └── d_latitude: 0.25
# [INFO]  └── time: 1464
# [INFO]  └── d_time: 36000000000000 nanoseconds
# [INFO] ------------------------------------------
# [INFO] Normalization types: {'VAR_2T': 'standard'}
# [INFO] VAR_2T: Index 0
# [INFO] ------ Normalization Statistics (norm_mapping) ------
# [INFO]
# [VAR_2T_fine]
#  └── vmin=229.04872131347656
#  └── vmax=321.4019470214844
#  └── vmean=286.3158874511719
#  └── vstd=12.632543563842773
#  └── median=289.16717529296875
#  └── iqr=17.32952880859375
#  └── q1=278.6593017578125
#  └── q3=295.98883056640625
# [INFO]
# [VAR_10U_fine]
#  └── vmin=-31.68634033203125
#  └── vmax=27.692642211914062
#  └── vmean=0.36626559495925903
#  └── vstd=3.4527664184570312
#  └── median=0.406768798828125
#  └── iqr=3.959686279296875
#  └── q1=-1.5895233154296875
#  └── q3=2.3701629638671875
# [INFO]
# [VAR_10V_fine]
#  └── vmin=-25.834945678710938
#  └── vmax=31.813018798828125
#  └── vmean=-0.05726669356226921
#  └── vstd=3.699695110321045
#  └── median=0.1490478515625
#  └── iqr=4.2974090576171875
#  └── q1=-2.101776123046875
#  └── q3=2.1956329345703125
# [INFO]
# [VAR_TP_fine]
#  └── vmin=0.0
#  └── vmax=0.03237342834472656
#  └── vmean=9.736002539284527e-05
#  └── vstd=0.0004453345318324864
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_fine]
#  └── vmin=225.20355224609375
#  └── vmax=303.56671142578125
#  └── vmean=280.1187744140625
#  └── vstd=12.384744644165039
#  └── median=282.1183776855469
#  └── iqr=17.892791748046875
#  └── q1=271.99053955078125
#  └── q3=289.8833312988281
# [INFO]
# [VAR_SSTK_fine]
#  └── vmin=269.893798828125
#  └── vmax=310.327392578125
#  └── vmean=294.448974609375
#  └── vstd=7.419081211090088
#  └── median=296.134521484375
#  └── iqr=8.3564453125
#  └── q1=291.531005859375
#  └── q3=299.887451171875
# [INFO]
# [VAR_SKT_fine]
#  └── vmin=228.62649536132812
#  └── vmax=340.2298583984375
#  └── vmean=286.8110656738281
#  └── vstd=13.723491668701172
#  └── median=289.64111328125
#  └── iqr=18.9613037109375
#  └── q1=278.0294189453125
#  └── q3=296.99072265625
# [INFO]
# [VAR_ST_fine]
#  └── vmin=228.62649536132812
#  └── vmax=340.2298583984375
#  └── vmean=286.93658447265625
#  └── vstd=13.66016674041748
#  └── median=289.69012451171875
#  └── iqr=19.09234619140625
#  └── q1=278.03558349609375
#  └── q3=297.1279296875
# [INFO]
# [VAR_TCWV_fine]
#  └── vmin=0.22132164239883423
#  └── vmax=85.15592193603516
#  └── vmean=19.793996810913086
#  └── vstd=13.685070037841797
#  └── median=16.279447555541992
#  └── iqr=20.19249439239502
#  └── q1=8.689061164855957
#  └── q3=28.881555557250977
# [INFO]
# [VAR_2T_fine_log]
#  └── vmin=5.438291072845459
#  └── vmax=5.77579927444458
#  └── vmean=5.659588813781738
#  └── vstd=0.0450122207403183
#  └── median=5.670457363128662
#  └── iqr=0.06012248992919922
#  └── q1=5.633572101593018
#  └── q3=5.693694591522217
# [INFO]
# [VAR_10U_fine_log]
#  └── vmin=0.0
#  └── vmax=3.3566408157348633
#  └── vmean=0.630792498588562
#  └── vstd=0.7104994654655457
#  └── median=0.341295450925827
#  └── iqr=1.214961051940918
#  └── q1=0.0
#  └── q3=1.214961051940918
# [INFO]
# [VAR_10V_fine_log]
#  └── vmin=0.0
#  └── vmax=3.4908254146575928
#  └── vmean=0.5861193537712097
#  └── vstd=0.6988515257835388
#  └── median=0.13893364369869232
#  └── iqr=1.1617851257324219
#  └── q1=0.0
#  └── q3=1.1617851257324219
# [INFO]
# [VAR_TP_fine_log]
#  └── vmin=0.0
#  └── vmax=0.03186045214533806
#  └── vmean=9.725653217174113e-05
#  └── vstd=0.0004441823693923652
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_fine_log]
#  └── vmin=5.421435356140137
#  └── vmax=5.718890190124512
#  └── vmean=5.637784481048584
#  └── vstd=0.04488770291209221
#  └── median=5.645864963531494
#  └── iqr=0.06348514556884766
#  └── q1=5.609436988830566
#  └── q3=5.672922134399414
# [INFO]
# [VAR_SSTK_fine_log]
#  └── vmin=5.60172700881958
#  └── vmax=5.740845203399658
#  └── vmean=5.688181400299072
#  └── vstd=0.025550369173288345
#  └── median=5.69418478012085
#  └── iqr=0.028165340423583984
#  └── q1=5.678570747375488
#  └── q3=5.706736087799072
# [INFO]
# [VAR_SKT_fine_log]
#  └── vmin=5.436453819274902
#  └── vmax=5.832556247711182
#  └── vmean=5.661135196685791
#  └── vstd=0.04862700030207634
#  └── median=5.672089099884033
#  └── iqr=0.06574535369873047
#  └── q1=5.631317138671875
#  └── q3=5.6970624923706055
# [INFO]
# [VAR_ST_fine_log]
#  └── vmin=5.436453819274902
#  └── vmax=5.832556247711182
#  └── vmean=5.661587715148926
#  └── vstd=0.048360396176576614
#  └── median=5.672257900238037
#  └── iqr=0.06618309020996094
#  └── q1=5.6313395500183105
#  └── q3=5.6975226402282715
# [INFO]
# [VAR_TCWV_fine_log]
#  └── vmin=0.19993358850479126
#  └── vmax=4.456158638000488
#  └── vmean=2.7831106185913086
#  └── vstd=0.7609286904335022
#  └── median=2.849517822265625
#  └── iqr=1.1262438297271729
#  └── q1=2.2709975242614746
#  └── q3=3.3972413539886475
# [INFO]
# [VAR_2T_coarse]
#  └── vmin=231.1106414794922
#  └── vmax=317.4587097167969
#  └── vmean=286.2744445800781
#  └── vstd=12.475735664367676
#  └── median=289.1328125
#  └── iqr=17.11468505859375
#  └── q1=278.7331237792969
#  └── q3=295.8478088378906
# [INFO]
# [VAR_10U_coarse]
#  └── vmin=-21.51896095275879
#  └── vmax=21.438461303710938
#  └── vmean=0.3791687488555908
#  └── vstd=3.261948585510254
#  └── median=0.4203634262084961
#  └── iqr=3.678152084350586
#  └── q1=-1.411860466003418
#  └── q3=2.266291618347168
# [INFO]
# [VAR_10V_coarse]
#  └── vmin=-22.52874183654785
#  └── vmax=22.988109588623047
#  └── vmean=-0.05645933374762535
#  └── vstd=3.4837522506713867
#  └── median=0.14693546295166016
#  └── iqr=4.036676406860352
#  └── q1=-1.9780120849609375
#  └── q3=2.058664321899414
# [INFO]
# [VAR_TP_coarse]
#  └── vmin=0.0
#  └── vmax=0.023218277841806412
#  └── vmean=9.832954674493521e-05
#  └── vstd=0.0003440176951698959
#  └── median=0.0
#  └── iqr=3.2697804272174835e-05
#  └── q1=0.0
#  └── q3=3.2697804272174835e-05
# [INFO]
# [VAR_D2M_coarse]
#  └── vmin=227.51480102539062
#  └── vmax=301.0519714355469
#  └── vmean=280.09478759765625
#  └── vstd=12.215740203857422
#  └── median=281.9904479980469
#  └── iqr=17.661468505859375
#  └── q1=272.05743408203125
#  └── q3=289.7189025878906
# [INFO]
# [VAR_SSTK_coarse]
#  └── vmin=270.34332275390625
#  └── vmax=305.5076599121094
#  └── vmean=292.5169982910156
#  └── vstd=8.795150756835938
#  └── median=294.7130126953125
#  └── iqr=10.933807373046875
#  └── q1=288.31317138671875
#  └── q3=299.2469787597656
# [INFO]
# [VAR_SKT_coarse]
#  └── vmin=231.03900146484375
#  └── vmax=334.51080322265625
#  └── vmean=286.7804260253906
#  └── vstd=13.49194049835205
#  └── median=289.6012878417969
#  └── iqr=18.774444580078125
#  └── q1=278.14044189453125
#  └── q3=296.9148864746094
# [INFO]
# [VAR_ST_coarse]
#  └── vmin=231.0741424560547
#  └── vmax=334.51080322265625
#  └── vmean=286.9049377441406
#  └── vstd=13.402721405029297
#  └── median=289.6504211425781
#  └── iqr=18.90411376953125
#  └── q1=278.1444396972656
#  └── q3=297.0485534667969
# [INFO]
# [VAR_TCWV_coarse]
#  └── vmin=0.4617171883583069
#  └── vmax=75.78866577148438
#  └── vmean=19.75491714477539
#  └── vstd=13.40636920928955
#  └── median=16.368555068969727
#  └── iqr=19.981657028198242
#  └── q1=8.836700439453125
#  └── q3=28.818357467651367
# [INFO]
# [VAR_2T_coarse_log]
#  └── vmin=5.447214126586914
#  └── vmax=5.763493061065674
#  └── vmean=5.659465312957764
#  └── vstd=0.044454626739025116
#  └── median=5.6703386306762695
#  └── iqr=0.05938386917114258
#  └── q1=5.633835792541504
#  └── q3=5.6932196617126465
# [INFO]
# [VAR_10U_coarse_log]
#  └── vmin=0.0
#  └── vmax=3.110776424407959
#  └── vmean=0.6167603731155396
#  └── vstd=0.6906296610832214
#  └── median=0.35091277956962585
#  └── iqr=1.1836552619934082
#  └── q1=0.0
#  └── q3=1.1836552619934082
# [INFO]
# [VAR_10V_coarse_log]
#  └── vmin=0.0
#  └── vmax=3.177558183670044
#  └── vmean=0.5649643540382385
#  └── vstd=0.6782220005989075
#  └── median=0.13709357380867004
#  └── iqr=1.1179783344268799
#  └── q1=0.0
#  └── q3=1.1179783344268799
# [INFO]
# [VAR_TP_coarse_log]
#  └── vmin=0.0
#  └── vmax=0.022952834144234657
#  └── vmean=9.826572932070121e-05
#  └── vstd=0.0003434800310060382
#  └── median=0.0
#  └── iqr=3.269726948929019e-05
#  └── q1=0.0
#  └── q3=3.269726948929019e-05
# [INFO]
# [VAR_D2M_coarse_log]
#  └── vmin=5.431601047515869
#  └── vmax=5.710598945617676
#  └── vmean=5.637722492218018
#  └── vstd=0.04426100477576256
#  └── median=5.645412921905518
#  └── iqr=0.06267452239990234
#  └── q1=5.609682083129883
#  └── q3=5.672356605529785
# [INFO]
# [VAR_SSTK_coarse_log]
#  └── vmin=5.603384971618652
#  └── vmax=5.725242614746094
#  └── vmean=5.68147611618042
#  └── vstd=0.03042922541499138
#  └── median=5.689389228820801
#  └── iqr=0.03709602355957031
#  └── q1=5.66750955581665
#  └── q3=5.704605579376221
# [INFO]
# [VAR_SKT_coarse_log]
#  └── vmin=5.446905612945557
#  └── vmax=5.815654277801514
#  └── vmean=5.661067962646484
#  └── vstd=0.04781469702720642
#  └── median=5.671952247619629
#  └── iqr=0.0650930404663086
#  └── q1=5.631714820861816
#  └── q3=5.696807861328125
# [INFO]
# [VAR_ST_coarse_log]
#  └── vmin=5.447056770324707
#  └── vmax=5.815654277801514
#  └── vmean=5.6615166664123535
#  └── vstd=0.04743646830320358
#  └── median=5.672121047973633
#  └── iqr=0.06552743911743164
#  └── q1=5.6317291259765625
#  └── q3=5.697256565093994
# [INFO]
# [VAR_TCWV_coarse_log]
#  └── vmin=0.37961190938949585
#  └── vmax=4.341056823730469
#  └── vmean=2.7900803089141846
#  └── vstd=0.7469266057014465
#  └── median=2.854661464691162
#  └── iqr=1.1090037822723389
#  └── q1=2.2861204147338867
#  └── q3=3.3951241970062256
# [INFO]
# [VAR_2T_residual]
#  └── vmin=-20.920257568359375
#  └── vmax=21.579376220703125
#  └── vmean=0.04164712503552437
#  └── vstd=1.5219651460647583
#  └── median=0.030517578125
#  └── iqr=0.98223876953125
#  └── q1=-0.43994140625
#  └── q3=0.54229736328125
# [INFO]
# [VAR_10U_residual]
#  └── vmin=-29.087757110595703
#  └── vmax=29.122817993164062
#  └── vmean=-0.012903066352009773
#  └── vstd=0.9604038000106812
#  └── median=-0.010351181030273438
#  └── iqr=0.8234825134277344
#  └── q1=-0.4233999252319336
#  └── q3=0.4000825881958008
# [INFO]
# [VAR_10V_residual]
#  └── vmin=-30.490480422973633
#  └── vmax=33.75514221191406
#  └── vmean=-0.0008073379285633564
#  └── vstd=0.9775290489196777
#  └── median=-0.0026082992553710938
#  └── iqr=0.8361549377441406
#  └── q1=-0.41808319091796875
#  └── q3=0.4180717468261719
# [INFO]
# [VAR_TP_residual]
#  └── vmin=-0.017026737332344055
#  └── vmax=0.029841333627700806
#  └── vmean=-9.694650771052693e-07
#  └── vstd=0.00030207826057448983
#  └── median=0.0
#  └── iqr=5.470588803291321e-06
#  └── q1=-5.470588803291321e-06
#  └── q3=0.0
# [INFO]
# [VAR_D2M_residual]
#  └── vmin=-31.039138793945312
#  └── vmax=28.3192138671875
#  └── vmean=0.023892996832728386
#  └── vstd=1.4677867889404297
#  └── median=0.0244140625
#  └── iqr=0.987335205078125
#  └── q1=-0.45941162109375
#  └── q3=0.527923583984375
# [INFO]
# [VAR_SSTK_residual]
#  └── vmin=-17.443267822265625
#  └── vmax=13.81427001953125
#  └── vmean=-0.0350143201649189
#  └── vstd=0.7585651874542236
#  └── median=0.001617431640625
#  └── iqr=0.376678466796875
#  └── q1=-0.188629150390625
#  └── q3=0.18804931640625
# [INFO]
# [VAR_SKT_residual]
#  └── vmin=-28.566864013671875
#  └── vmax=28.982437133789062
#  └── vmean=0.03118680603802204
#  └── vstd=2.0454213619232178
#  └── median=0.019866943359375
#  └── iqr=1.16064453125
#  └── q1=-0.5408935546875
#  └── q3=0.6197509765625
# [INFO]
# [VAR_ST_residual]
#  └── vmin=-34.95600891113281
#  └── vmax=39.09918212890625
#  └── vmean=0.03217749670147896
#  └── vstd=2.273470878601074
#  └── median=0.019073486328125
#  └── iqr=1.18994140625
#  └── q1=-0.560211181640625
#  └── q3=0.629730224609375
# [INFO]
# [VAR_TCWV_residual]
#  └── vmin=-23.256834030151367
#  └── vmax=37.254486083984375
#  └── vmean=0.039075303822755814
#  └── vstd=1.738486886024475
#  └── median=-0.006313323974609375
#  └── iqr=1.2740097045898438
#  └── q1=-0.6151771545410156
#  └── q3=0.6588325500488281
# [INFO]
# [VAR_2T_residual_log]
#  └── vmin=0.0
#  └── vmax=3.117036819458008
#  └── vmean=0.28070369362831116
#  └── vstd=0.4261401295661926
#  └── median=0.030061179772019386
#  └── iqr=0.4332731068134308
#  └── q1=0.0
#  └── q3=0.4332731068134308
# [INFO]
# [VAR_10U_residual_log]
#  └── vmin=0.0
#  └── vmax=3.405282974243164
#  └── vmean=0.20981374382972717
#  └── vstd=0.3211251497268677
#  └── median=0.0
#  └── iqr=0.33653122186660767
#  └── q1=0.0
#  └── q3=0.33653122186660767
# [INFO]
# [VAR_10V_residual_log]
#  └── vmin=0.0
#  └── vmax=3.5483274459838867
#  └── vmean=0.2159300297498703
#  └── vstd=0.3264327943325043
#  └── median=0.0
#  └── iqr=0.34929803013801575
#  └── q1=0.0
#  └── q3=0.34929803013801575
# [INFO]
# [VAR_TP_residual_log]
#  └── vmin=0.0
#  └── vmax=0.029404744505882263
#  └── vmean=3.573554931790568e-05
#  └── vstd=0.00025026267394423485
#  └── median=0.0
#  └── iqr=1.0
#  └── q1=0.0
#  └── q3=0.0
# [INFO]
# [VAR_D2M_residual_log]
#  └── vmin=0.0
#  └── vmax=3.3782429695129395
#  └── vmean=0.2696094512939453
#  └── vstd=0.4076869487762451
#  └── median=0.02412080205976963
#  └── iqr=0.4239096939563751
#  └── q1=0.0
#  └── q3=0.4239096939563751
# [INFO]
# [VAR_SSTK_residual_log]
#  └── vmin=0.0
#  └── vmax=2.6955909729003906
#  └── vmean=0.13331298530101776
#  └── vstd=0.24127879738807678
#  └── median=0.0016161249950528145
#  └── iqr=0.17231273651123047
#  └── q1=0.0
#  └── q3=0.17231273651123047
# [INFO]
# [VAR_SKT_residual_log]
#  └── vmin=0.0
#  └── vmax=3.4006118774414062
#  └── vmean=0.3152047395706177
#  └── vstd=0.4903116822242737
#  └── median=0.019672170281410217
#  └── iqr=0.4822724163532257
#  └── q1=0.0
#  └── q3=0.4822724163532257
# [INFO]
# [VAR_ST_residual_log]
#  └── vmin=0.0
#  └── vmax=3.6913559436798096
#  └── vmean=0.3226388692855835
#  └── vstd=0.5073100328445435
#  └── median=0.01889386773109436
#  └── iqr=0.4884144961833954
#  └── q1=0.0
#  └── q3=0.4884144961833954
# [INFO]
# [VAR_TCWV_residual_log]
#  └── vmin=0.0
#  └── vmax=3.644260883331299
#  └── vmean=0.30773696303367615
#  └── vstd=0.4650293290615082
#  └── median=0.0
#  └── iqr=0.5061140656471252
#  └── q1=0.0
#  └── q3=0.5061140656471252
# [INFO]
#
#  └── vmin=0.0
#  └── vmax=359.75
#  └── vmean=179.875
#  └── vstd=103.92301940917969
#  └── median=None
#  └── iqr=None
#  └── q1=None
#  └── q3=None
# [INFO]
#
#  └── vmin=-90.0
#  └── vmax=90.0
#  └── vmean=0.0
#  └── vstd=52.03364181518555
#  └── median=None
#  └── iqr=None
#  └── q1=None
#  └── q3=None
# [INFO] ------------------------------------------------------
# [INFO] Using device: cuda
# [INFO] TensorBoard enabled at: runs/notebook_test/test_run_unet/
# [INFO] Creating train dataset:
# [INFO]  └── Original resolution: (145, 361)
# [INFO]  └── Adjusted to divisible-by-2^3 resolution: (144, 360)
# [INFO]  └── train years: [2019]
# [INFO]  └── train parameters - tbatch: 1800, sbatch: 12, shuffle: True
# [INFO]  └── Number of train files: 1
# [INFO] Spatial dimensions: 721 x 1440
# [INFO] batch size: 144 x 360
# [INFO] Opening constant variables file:
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5_
# const_sfc_variables.nc
# [INFO] Normalizing z
# [INFO] z - Weighted Mean: 2270.3749, Weighted Std: 6149.4917
# [INFO] Loaded constant variables: ['z', 'lsm']
# [INFO] Constant variables shape: (2, 721, 1440)
# [INFO] Training mode: sbatch=12, tbatch=1800
# [INFO]   train dataset size: 17520
# [INFO]   train data loader batches: 251
# [INFO] Training dataset loaded with image resolution: (144, 360)
# [INFO] Creating validation dataset:
# [INFO]  └── Original resolution: (145, 361)
# [INFO]  └── Adjusted to divisible-by-2^3 resolution: (144, 360)
# [INFO]  └── validation years: [2020]
# [INFO]  └── validation parameters - tbatch: 70, sbatch: 12, shuffle: False
# [INFO]  └── Number of validation files: 1
# [INFO] Spatial dimensions: 721 x 1440
# [INFO] batch size: 144 x 360
# [INFO] Opening constant variables file:
# /leonardo_work/EUHPC_D27_095/kkingston/AI-Downscaling/data/data_FOURxDaily/ERA5_
# const_sfc_variables.nc
# [INFO] Normalizing z
# [INFO] z - Weighted Mean: 2270.3749, Weighted Std: 6149.4917
# [INFO] Loaded constant variables: ['z', 'lsm']
# [INFO] Constant variables shape: (2, 721, 1440)
# [INFO] Generated 20 evaluation blocks (5 x 4 grid)
# [INFO] Evaluation mode: Generated 20 spatial slices
# [INFO] Validation time batches: [488 495 502 509 516 523 530 537 544 551 558 565
# 572 579 587 594 601 608
#  615 622 629 636 643 650 657 664 671 678 686 693 700 707 714 721 728 735
#  742 749 756 763 770 777 785 792 799 806 813 820 827 834 841 848 855 862
#  869 876 884 891 898 905 912 919 926 933 940 947 954 961 968 976]
# [INFO]   validation dataset size: 1400
# [INFO]   validation data loader batches: 20
# [INFO] Validation dataset loaded with image resolution: (144, 360)
# [INFO] ------ Model and Loss info ------
# [INFO] Label dimension: 4 (time_normalization: cos_sin)
# [INFO] Using direct U-Net & UnetLoss
# [INFO] Architecture ADM / DhariwalUNet selected for direct U-Net
# [INFO] Instantiating model...
# [INFO] Diffusion model disabled, direct U-Net, no preconditioning
# [INFO] Model Summary:
# [INFO]    └── Model Type: DhariwalUNet
# [INFO]    └── Preconditioner: UNET
# [INFO]    └── Architecture: ADM
# [INFO]    └── Input Channels: 5
# [INFO]    └── Output Channels: 1
# [INFO]    └── Label Dimension: 4
# [INFO]    └── Image Resolution: (144, 360)
# [INFO]    └── FP16 Enabled: N/A for direct U-Net
# [INFO]    └── Model Parameters - Total: 92,129,025, Trainable: 92129025
# [INFO] Network Architecture:
# [INFO]    └── model_channels: 128
# [INFO]    └── channel_mult: [1, 2, 3, 4]
# [INFO]    └── num_blocks: 2
# [INFO]    └── diffusion_model: False
# [INFO] Device: cuda:0
# [INFO] Model Data Type: torch.float32
# [INFO] Loss function instantiated: UnetLoss
# [INFO]   └── Loss Type: UNET Diffusion Loss
# [INFO] Model Parameters - Total: 92,129,025, Trainable: 92,129,025
# [INFO] GradScaler initialized for CUDA
# [INFO] Tracking metrics: ['MAE', 'NMAE', 'RMSE', 'R2', 'PEARSON', 'KL']
# [INFO] Validation metrics: ['VAR_2T_pred_vs_fine_MAE',
# 'VAR_2T_coarse_vs_fine_MAE', 'VAR_2T_pred_vs_fine_NMAE',
# 'VAR_2T_coarse_vs_fine_NMAE', 'VAR_2T_pred_vs_fine_RMSE',
# 'VAR_2T_coarse_vs_fine_RMSE', 'VAR_2T_pred_vs_fine_R2',
# 'VAR_2T_coarse_vs_fine_R2', 'VAR_2T_pred_vs_fine_PEARSON',
# 'VAR_2T_coarse_vs_fine_PEARSON', 'VAR_2T_pred_vs_fine_KL',
# 'VAR_2T_coarse_vs_fine_KL', 'average_pred_vs_fine_MAE',
# 'average_coarse_vs_fine_MAE', 'average_pred_vs_fine_NMAE',
# 'average_coarse_vs_fine_NMAE', 'average_pred_vs_fine_RMSE',
# 'average_coarse_vs_fine_RMSE', 'average_pred_vs_fine_R2',
# 'average_coarse_vs_fine_R2', 'average_pred_vs_fine_PEARSON',
# 'average_coarse_vs_fine_PEARSON', 'average_pred_vs_fine_KL',
# 'average_coarse_vs_fine_KL']
# [INFO] Model saving enabled
# [INFO] Using 4 GPUs!
# [INFO] Start training...
# Training Epoch 0:   0%|                                 | 0/251 [00:00<?, ?it/s][INFO] batch idx:0, features shape:torch.Size([70, 5, 144, 360]), targets
# shape:torch.Size([70, 1, 144, 360])
# Training Epoch 0: 100%|█| 251/251 [07:52<00:00,  1.88s/it, Loss=0.0030, Avg Loss
# [INFO] Running validation for epoch 0...
# [INFO] EDM Sampler parameters: steps=20
# Validation Epoch 0:   0%|                                | 0/20 [00:00<?, ?it/s][INFO] Validation batch idx:0
# features shape:torch.Size([70, 5, 144, 360]), targets shape:torch.Size([70, 1,
# 144, 360])
# coarse shape:torch.Size([70, 1, 144, 360]), fine shape:torch.Size([70, 1, 144,
# 360])
# lat shape:torch.Size([70, 144]), lon shape:torch.Size([70, 360])
# Validation Epoch 0: 100%|█| 20/20 [00:16<00:00,  1.23it/s, Val Loss=0.0033, Avg
# [INFO] Validation Epoch 0 - Average Loss: 0.0034
# [INFO] ============================================================
# [INFO] VALIDATION METRICS SUMMARY:
# [INFO] ============================================================
# [INFO] OVERALL MAE METRICS:
# [INFO]  └── Average Prediction vs Fine MAE: 0.4459 ± 0.0094
# [INFO]  └── Average Coarse vs Fine MAE: 0.7822 ± 0.0181
# [INFO]
# [INFO] OVERALL NMAE METRICS:
# [INFO]  └── Average Prediction vs Fine NMAE: 0.0016 ± 0.0000
# [INFO]  └── Average Coarse vs Fine NMAE: 0.0028 ± 0.0001
# [INFO]
# [INFO] OVERALL RMSE METRICS:
# [INFO]  └── Average Prediction vs Fine RMSE: 0.7408 ± 0.0187
# [INFO]  └── Average Coarse vs Fine RMSE: 1.4064 ± 0.0368
# [INFO]
# [INFO] OVERALL R2 METRICS:
# [INFO]  └── Average Prediction vs Fine R2: 0.9988 ± 0.0001
# [INFO]  └── Average Coarse vs Fine R2: 0.9956 ± 0.0006
# [INFO]
# [INFO] OVERALL PEARSON METRICS:
# [INFO]  └── Average Prediction vs Fine PEARSON: 0.9994 ± 0.0001
# [INFO]  └── Average Coarse vs Fine PEARSON: 0.9978 ± 0.0003
# [INFO]
# [INFO] OVERALL KL METRICS:
# [INFO]  └── Average Prediction vs Fine KL: 0.0008 ± 0.0002
# [INFO]  └── Average Coarse vs Fine KL: 0.0043 ± 0.0028
# [INFO]
# [INFO] PER-VARIABLE METRICS:
# [INFO]  └── VAR_2T:
# [INFO]    └── MAE:
# [INFO]        └── Model Pred vs Fine: 0.4459 ± 0.0094
# [INFO]        └── Coarse vs Fine:     0.7822 ± 0.0181
# [INFO]    └── NMAE:
# [INFO]        └── Model Pred vs Fine: 0.0016 ± 0.0000
# [INFO]        └── Coarse vs Fine:     0.0028 ± 0.0001
# [INFO]    └── RMSE:
# [INFO]        └── Model Pred vs Fine: 0.7408 ± 0.0187
# [INFO]        └── Coarse vs Fine:     1.4064 ± 0.0368
# [INFO]    └── R2:
# [INFO]        └── Model Pred vs Fine: 0.9988 ± 0.0001
# [INFO]        └── Coarse vs Fine:     0.9956 ± 0.0006
# [INFO]    └── PEARSON:
# [INFO]        └── Model Pred vs Fine: 0.9994 ± 0.0001
# [INFO]        └── Coarse vs Fine:     0.9978 ± 0.0003
# [INFO]    └── KL:
# [INFO]        └── Model Pred vs Fine: 0.0008 ± 0.0002
# [INFO]        └── Coarse vs Fine:     0.0043 ± 0.0028
# [INFO] Saved validation metrics heatmap to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_metrics_epoch_0.png
# [INFO] Reconstructing and plots ...
# [INFO] Dataset reconstruction info:
# [INFO]  └── time_batchs: 70
# [INFO]  └── sbatch: 20
# [INFO]  └── total dataset samples: 1400
# [INFO]  └── total batch samples: 1400
# [INFO] Sample shape: C=1, H=144, W=360
# [INFO] Initialized predictions with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized coarse with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized fine with shape: torch.Size([70, 20, 1, 144, 360])
# [INFO] Initialized lat with shape: torch.Size([70, 20, 144])
# [INFO] Initialized lon with shape: torch.Size([70, 20, 360])
# [INFO] Created index mapping for 1400 samples
# [INFO] Starting reconstruction process...
# [INFO] Processing batch 1/20 with size 70
# [INFO] Processing batch 2/20 with size 70
# [INFO] Processing batch 3/20 with size 70
# [INFO] Processing batch 4/20 with size 70
# [INFO] Processing batch 5/20 with size 70
# [INFO] Processing batch 6/20 with size 70
# [INFO] Processing batch 7/20 with size 70
# [INFO] Processing batch 8/20 with size 70
# [INFO] Processing batch 9/20 with size 70
# [INFO] Processing batch 10/20 with size 70
# [INFO] Processing batch 11/20 with size 70
# [INFO] Processing batch 12/20 with size 70
# [INFO] Processing batch 13/20 with size 70
# [INFO] Processing batch 14/20 with size 70
# [INFO] Processing batch 15/20 with size 70
# [INFO] Processing batch 16/20 with size 70
# [INFO] Processing batch 17/20 with size 70
# [INFO] Processing batch 18/20 with size 70
# [INFO] Processing batch 19/20 with size 70
# [INFO] Processing batch 20/20 with size 70
# [INFO] Successfully reconstructed 1400 samples
# [INFO] Reconstruction completed successfully
# [INFO] Generating block wise plots for epoch 0...
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=290.9628 | Pred=290.8604 | Coarse=290.6276
#   q=0.950 | Truth=294.1849 | Pred=294.0463 | Coarse=293.7257
#   q=0.975 | Truth=297.3305 | Pred=297.2178 | Coarse=296.7240
#   q=0.990 | Truth=300.1063 | Pred=299.9287 | Coarse=299.4454
#   q=0.995 | Truth=301.5690 | Pred=301.3090 | Coarse=300.9200
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_qq_epoch_0_spatial_block_000.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_hexbin_epoch_0_sblock_000.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_comparison_hexbin_epoch_0_sblock_000.png
# [PDF stats] Temperature [K]
#   Predictions: μ=279.868, σ=8.067
#   Ground Truth: μ=279.921, σ=8.091
#   Coarse: μ=279.920, σ=7.922
#   KL Divergence: 0.0016
#   Correlation: 0.9970
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_pdfs_epoch_0_sblock_000.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_power_spectra_epoch_0_sblock_000.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_mae_map_epoch_0_sblock_000.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_plot_surface_epoch_0_sblock_000.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_temporal_series_epoch_0_sblock_000.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=289.9468 | Pred=289.8161 | Coarse=289.4085
#   q=0.950 | Truth=293.5501 | Pred=293.4401 | Coarse=292.7796
#   q=0.975 | Truth=296.6164 | Pred=296.4691 | Coarse=295.9776
#   q=0.990 | Truth=299.7068 | Pred=299.5087 | Coarse=298.9757
#   q=0.995 | Truth=301.2311 | Pred=300.9889 | Coarse=300.3865
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_qq_epoch_0_spatial_block_001.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_hexbin_epoch_0_sblock_001.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_comparison_hexbin_epoch_0_sblock_001.png
# [PDF stats] Temperature [K]
#   Predictions: μ=278.435, σ=7.977
#   Ground Truth: μ=278.483, σ=8.004
#   Coarse: μ=278.483, σ=7.757
#   KL Divergence: 0.0013
#   Correlation: 0.9962
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_pdfs_epoch_0_sblock_001.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_power_spectra_epoch_0_sblock_001.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_mae_map_epoch_0_sblock_001.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_plot_surface_epoch_0_sblock_001.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_temporal_series_epoch_0_sblock_001.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth
png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_comparison_hexbin_epoch_0_sblock_018.png
# [PDF stats] Temperature [K]
#   Predictions: μ=256.252, σ=17.585
#   Ground Truth: μ=256.262, σ=17.641
#   Coarse: μ=256.279, σ=17.175
#   KL Divergence: 0.0010
#   Correlation: 0.9982
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_pdfs_epoch_0_sblock_018.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_power_spectra_epoch_0_sblock_018.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_mae_map_epoch_0_sblock_018.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_plot_surface_epoch_0_sblock_018.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_temporal_series_epoch_0_sblock_018.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [QQ Quantiles] Temperature [K]
#   q=0.900 | Truth=273.5624 | Pred=273.5676 | Coarse=273.4959
#   q=0.950 | Truth=275.9487 | Pred=275.9229 | Coarse=275.7810
#   q=0.975 | Truth=277.5673 | Pred=277.5204 | Coarse=277.2873
#   q=0.990 | Truth=278.9640 | Pred=278.9537 | Coarse=278.6890
#   q=0.995 | Truth=279.7167 | Pred=279.6644 | Coarse=279.3722
# [INFO] Saved QQ plot to
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_qq_epoch_0_spatial_block_019.png
# [INFO] Saved validation hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_hexbin_epoch_0_sblock_019.png
# [INFO] Saved comparison hexbin plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_comparison_hexbin_epoch_0_sblock_019.png
# [PDF stats] Temperature [K]
#   Predictions: μ=250.062, σ=18.292
#   Ground Truth: μ=250.054, σ=18.324
#   Coarse: μ=250.059, σ=17.986
#   KL Divergence: 0.0013
#   Correlation: 0.9979
# [INFO] Saved validation PDFs plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_validation_pdfs_epoch_0_sblock_019.png
# [INFO] Saved power spectra plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_power_spectra_epoch_0_sblock_019.png
# [INFO] Saved MAE map to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_mae_map_epoch_0_sblock_019.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate correlation map to: 0
# [INFO] Saved surface plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_plot_surface_epoch_0_sblock_019.png
# [INFO] Saved temporal series plot to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/results/notebook_test/test_run_u
# net/train_temporal_series_epoch_0_sblock_019.png
# ERROR: need at least 2 variables but num_vars < 2
# [INFO] Saved multivariate spatial correlation time series to: 0
# [INFO] Scheduler step with mean validation MAE (all 1 epochs): 0.4459
# [INFO] Epoch 0 completed - Train Loss: 0.0045
# [INFO] Epoch 0 completed - Val Loss: 0.0034
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_epoch0000_unet_model.pth.tar
# [INFO] ✅ Checkpoint saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_epoch0000_unet_model.pth.tar
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_best_model.pth.tar
# [INFO] ✅ Best model saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_best_model.pth.tar
# [INFO]  └── Validation loss: 0.0034
# [INFO] Generating training summary plots...
# [INFO] Training summary plots generated successfully!
# [INFO] Generating spatiotemporal coverage plots...
# [INFO] Spatiotemporal coverage plots completed!
# [INFO] Saving checkpoint to:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_final_model_epoch1.pth.tar
# [INFO] ✅ Final model saved:
# /leonardo_work/EUHPC_D27_095/kkingston/IPSL-AID/checkpoints/notebook_test/test_r
# un_unet/run_20260323_142528_final_model_epoch1.pth.tar
# [INFO]  └── Total samples: 0, Total batches: 0
# [INFO] Final model checkpoint saved successfully!
# [INFO] Training process completed successfully!
